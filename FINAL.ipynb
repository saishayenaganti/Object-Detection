# %% [markdown]
# <a href="https://colab.research.google.com/github/saishayenaganti/Object-Detection/blob/main/FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/107.7 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain
# Out:
# /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test	valid	    yolov8s.pt
# README.dataset.txt  runs		 train	yolov8n.pt

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
# !pip install --upgrade torch torchvision torchaudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 87.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.0+cu121
#     Uninstalling torchvision-0.18.0+cu121:
#       Successfully uninstalled torchvision-0.18.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.3.0+cu121
# ...

# %%
# %cd /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/data.yaml' epochs=25 imgsz=640 plots=True batch=16
# Out:
# /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain
# Ultralytics YOLOv8.2.41 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pip install torch torchvision torchaudio

# %%
# !ls runs/detect/train3/
# Out:
# args.yaml					     R_curve.png	 val_batch0_labels.jpg
# confusion_matrix_normalized.png			     results.csv	 val_batch0_pred.jpg
# confusion_matrix.png				     results.png	 val_batch1_labels.jpg
# events.out.tfevents.1719211133.d6fc59ca2b97.19903.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					     train_batch1.jpg	 val_batch2_labels.jpg
# labels_correlogram.jpg				     train_batch2.jpg	 val_batch2_pred.jpg
# labels.jpg					     train_batch420.jpg  weights
# P_curve.png					     train_batch421.jpg
# PR_curve.png					     train_batch422.jpg

# %%
Image(filename='runs/detect/train3/confusion_matrix_normalized.png', width=600)

# %%
Image(filename='runs/detect/train3/PR_curve.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/runs/detect/train3/val_batch2_pred.jpg', width=600)

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/test/images
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/63 /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/test/images/IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg: 640x480 1 puffin, 628.9ms
# image 2/63 /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/test/images/IMG_2301_jpeg_jpg.rf.2c19ae5efbd1f8611b5578125f001695.jpg: 640x480 26 penguins, 771.3ms
# image 3/63 /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/test/images/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg: 640x480 10 penguins, 840.5ms
# image 4/63 /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/test/images/IMG_2347_jpeg_jpg.rf.7c71ac4b9301eb358cd4a832844dedcb.jpg: 640x480 1 penguin, 510.4ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt conf=0.25 source=/content/fish2.jpeg
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/fish2.jpeg: 448x640 16 fishs, 2 jellyfishs, 770.8ms
# Speed: 12.0ms preprocess, 770.8ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob('/content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/runs/detect/predict3/fish2.jpeg')[:3]:
      display(Image(filename=image_path, width=400))
      print("\n")

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob('/content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/runs/detect/predict2/IMG_8582_MOV-0_jpg.rf.aa8304d7a5112d63c8841d96160d42cd.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# !yolo task=detect mode=val model=runs/detect/train3/weights/best.pt data='/content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/data.yaml'
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 4.02MB/s]
# val: Scanning /content/drive/MyDrive/underwater/miniunder/aquarium_pretrain/valid/labels.cache... 127 images, 0 backgrounds, 0 corrupt: 100% 127/127 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [01:50<00:00, 13.77s/it]
#                    all        127        909       0.81      0.732      0.775      0.497
#                   fish         63        459      0.853      0.746      0.829        0.5
#              jellyfish          9        155      0.823      0.872       0.91      0.517
#                penguin         17        104       0.74       0.76      0.761      0.358
#                 puffin         15         74      0.679      0.446      0.524      0.291
# ...

# %%
precision = 0.98
recall = 0.91
# Calculate accuracy
accuracy = (precision * recall) / (precision + recall - precision * recall)
print(f"Estimated Accuracy: {accuracy:.4f}")
# Out:
# Estimated Accuracy: 0.8934
